# %%
# %matplotlib inline
import gluonbook as gb
from mxnet import autograd, gluon, init, nd
from mxnet.gluon import data as gdata, loss as gloss, nn
import numpy as np
import pandas as pd

# %%
train_data = pd.read_csv('../data/kaggle_house_pred_train.csv')
test_data = pd.read_csv('../data/kaggle_house_pred_test.csv')

# %%
train_data.shape
test_data.shape
# Out:
# (1459, 80)

# %%
train_data.head() #Glance of first five columns
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train_data.iloc[0:3, [1, 2, 3, -3, -2, -1]]
# Out:
#    MSSubClass MSZoning  LotFrontage SaleType SaleCondition  SalePrice
# 0          60       RL         65.0       WD        Normal     208500
# 1          20       RL         80.0       WD        Normal     181500
# 2          60       RL         68.0       WD        Normal     223500

# %%
train_data.iloc[:2, 1:-1]
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig      ...       ScreenPorch PoolArea PoolQC  \
# 0         Lvl    AllPub    Inside      ...                 0        0    NaN
# 1         Lvl    AllPub       FR2      ...                 0        0    NaN
#
#   Fence MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 0   NaN         NaN       0       2    2008        WD         Normal
# 1   NaN         NaN       0       5    2007        WD         Normal
#
# [2 rows x 79 columns]

# %%
test_data.iloc[:2, 1:]
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          20       RH         80.0    11622   Pave   NaN      Reg
# 1          20       RL         81.0    14267   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig      ...       ScreenPorch PoolArea PoolQC  \
# 0         Lvl    AllPub    Inside      ...               120        0    NaN
# 1         Lvl    AllPub    Corner      ...                 0        0    NaN
#
#    Fence MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 0  MnPrv         NaN       0       6    2010        WD         Normal
# 1    NaN        Gar2   12500       6    2010        WD         Normal
#
# [2 rows x 79 columns]

# %%
#See difference between iloc and loc
all_data = pd.concat((train_data.loc[:,'MSSubClass':'SaleCondition'],
                      test_data.loc[:,'MSSubClass':'SaleCondition']))

# %%
all_features = pd.concat((train_data.iloc[:, 1:-1], test_data.iloc[:, 1:]))

# %%
# indice = all_features.dtypes.index
# numerical_features = []
# for index in indice:
#     if all_features[index].dtypes != 'object':
#         numerical_features.append(index)
        
# print(numerical_features)

# %%
numeric_features = all_features.dtypes[all_features.dtypes != 'object'].index
#Excluding all categorical features

print(numerical_features)
# Out:
# ['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold']

# %%
#Standardizating numeric features, speed up the gradient decending
#两个特征区间相差非常大时, 形成的等高线偏椭圆，迭代时很有可能走垂直长轴，从而导致需要迭代很多次才能收敛
# for index in numeric_features:
#     all_features[index] = map(lambda x: (x - x.mean()) / (x.std()), all_features[index])

# #Filling NaN's with the mean of the column
# all_features = all_features.fillna(all_features.mean())

# %%
numeric_features = all_features.dtypes[all_features.dtypes != 'object'].index
all_features[numeric_features] = all_features[numeric_features].apply(lambda x: (x - x.mean()) / (x.std()))
all_features = all_features.fillna(all_features.mean())

# %%
#Get dummy variables
all_features = pd.get_dummies(all_features, dummy_na=True)
all_features.shape
# Out:
# (2919, 331)

# %%
n_train = train_data.shape[0] #Get row number of train data
X_train = nd.array(all_features[:n_train].values) #Separate trainset and testset and convert to numpy type
X_test = nd.array(all_features[n_train:].values) # Then convert numpy array to nd array
y = nd.array(train_data.SalePrice.values).reshape((-1, 1)) #Train labels

# %%
#Define loss function, I use L2-norm loss function
loss = gloss.L2Loss()

def get_net():
    net = nn.Sequential() #Use a fully connected layer with sequential container
    net.add(nn.Dense(1))
    # Set weight parameters are random values that fullfill the normal distribution
    # which has 0 as average and 0.01 as standard deviation
    net.initialize() 
    return net

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_log_error

# %%
# def k_fold(model, X_train, y, scoring='neg_mean_squared_log_error', cv=5):
#     rmse = np.sqrt(-cross_val_score(model, X_train, y, scoring=scoring, cv=cv))
#     return rmse

# %%
# Find log root-mean-square error
def log_rmse(net, train_features, train_labels):
    # Limits the values in interval [1,float('inf')) for log calculation
    clipped_preds = nd.clip(net(train_features), 1, float('inf'))
#     rsme = mean_squared_log_error(clipped_preds.asnumpy(), train_labels.asnumpy())
    rmse = nd.sqrt(2 * loss(clipped_preds.log(), train_labels.log()).mean())
    return rmse.asscalar()

# %%
def train(net, train_features, train_labels, test_features, test_labels, num_epochs, 
          learning_rate, weight_decay, batch_size):
    dataset = gdata.ArrayDataset(train_features, train_labels)
    data_iter = gdata.DataLoader(dataset, batch_size, shuffle=True)# Loading data
    train_ls, test_ls = [], []
    # Define the trainer, with adam as optimization function, and two hyper-parameters 
    # Learning rate and weight decay. Batch size is another hyper-parameter. 
    trainer = gluon.Trainer(net.collect_params(), 'adam', 
                            {'learning_rate':learning_rate, 'wd':weight_decay})
    for epoch in range(num_epochs):
        for X, y in data_iter:
            with autograd.record(): # Automatically find gradient
                l = loss(net(X), y) 
            l.backward()
            trainer.step(batch_size)
        train_ls.append(log_rmse(net, train_features, train_labels))
        if test_labels is not None:
            test_ls.append(log_rmse(net, test_features, test_labels))
    return train_ls, test_ls

# %%
def get_k_fold_data(k, i, X, y):
    assert k > 1
    fold_size = X.shape[0] // k
    X_train, y_train = None, None
    for j in range(k):
        idx = slice(j * fold_size, (j + 1) * fold_size)
        X_part, y_part = X[idx, :], y[idx]
        if j == i:
            X_valid, y_valid = X_part, y_part
        elif X_train is None:
            X_train, y_train = X_part, y_part
        else:
            X_train = nd.concat(X_train, X_part, dim=0)
            y_train = nd.concat(y_train, y_part, dim=0)
    return X_train, y_train, X_valid, y_valid

# %%
def k_fold(k, X_train, y_train, num_epochs, learning_rate, batch_size, weight_decay):
    train_l_sum, test_l_sum = 0, 0
    for i in range(k):
        data = get_k_fold_data(k, i, X_train, y_train)
        net = get_net()
        train_ls, test_ls = train(net, *data, num_epochs, 
                                  learning_rate, weight_decay, batch_size)
        train_l_sum += train_ls[-1]
        test_l_sum += test_ls[-1]
        if i == 0:
            gb.semilogy(range(1, num_epochs + 1), train_ls, 'epochs', 'rmse', 
                        range(1, num_epochs + 1), test_ls, 
                        ['train', 'valid'])
        print('fold %d, train rmse: %f, valid rmse: %f' % (i, train_ls[-1], test_ls[-1]))
    return train_l_sum / k, test_l_sum / k

# %%
k, num_epochs, lr, weight_decay, batch_size = 5, 110, 16, 0, 72
verbose_epoch = num_epochs - 2
train_l, valid_l = k_fold(k, X_train, y, num_epochs, lr, batch_size, weight_decay)

print('%d-fold validation: avg train rmse: %f, avg valid rmse: %f' % (k, train_l, valid_l))
# Out:
# fold 0, train rmse: 0.136037, valid rmse: 0.143521
# fold 1, train rmse: 0.133768, valid rmse: 0.148747
# fold 2, train rmse: 0.132101, valid rmse: 0.141564
# fold 3, train rmse: 0.137161, valid rmse: 0.140565
# fold 4, train rmse: 0.129980, valid rmse: 0.169927
# 5-fold validation: avg train rmse: 0.133809, avg valid rmse: 0.148865

# %%
net = get_net()
preds = net(X_test).asnumpy()
pp = pd.Series(preds.reshape(1, -1)[0])

# %%
def train_and_pred(train_features, test_features, train_labels, test_data,
    num_epochs, lr, weight_decay, batch_size):
    net = get_net()
    train_ls, _ = train(net, train_features, train_labels, None, None, 
                        num_epochs, lr, weight_decay, batch_size)
    gb.semilogy(range(1, num_epochs + 1), train_ls, 'epochs', 'rmse')
    print('train rmse %f' % train_ls[-1])
    preds = net(test_features).asnumpy()
    test_data['SalePrice'] = pd.Series(preds.reshape(1, -1)[0])
    submission = pd.concat([test_data['Id'], test_data['SalePrice']], axis=1)
    submission.to_csv('submission.csv', index=False)

# %%
train_and_pred(X_train, X_test, y, test_data, num_epochs, lr, weight_decay, batch_size)
# Out:
# train rmse 0.131158
